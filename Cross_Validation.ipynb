# %% [markdown]
# <a href="https://colab.research.google.com/github/zhangtaira71/house-prices/blob/main/Cross_Validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from xgboost import XGBRegressor
import pandas as pd

import os

print(os.listdir('/'))

# !find / -name train.csv 2>/dev/null

train = pd.read_csv("/content/train.csv")

print(train.shape)

features = [
    'OverallQual',
    'GrLivArea',
    'GarageCars',
    'TotalBsmtSF',
    'FullBath',
    'YearBuilt',
    'GarageArea',
    'LotArea'
]

X = train[features]
# y = train['SalePrice']

import numpy as np

y = train["SalePrice"]

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

model = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)

scores = cross_val_score(
    model,
    X,
    y,
    cv=5,
    scoring="neg_mean_absolute_error"
)

print(scores)
print("Average MAE =", -scores.mean())
# Out:
# ['bin', 'usr', 'lib', 'libx32', 'var', 'tmp', 'lib64', 'home', 'proc', 'etc', 'sys', 'media', 'opt', 'mnt', 'root', 'dev', 'lib32', 'sbin', 'boot', 'srv', 'run', 'kaggle', 'content', '.dockerenv', 'datalab', 'tools', 'python-apt', 'python-apt.tar.xz']
# /content/train.csv
# (1460, 81)
# [-20330.26209586 -19729.55816047 -19815.34167808 -18149.90344896
#  -21553.21666341]
# Average MAE = 19915.6564093548
